# %%
import random

# %%
places = [1, 2, 3, 4, 5, 6, 7, 8, 9]
playerTurn = True
playerChoices = []
compChoices = []
play = True
win = False

# %%
def bb():

    print('       |       |')
    print('   {}   |   {}   |   {}' .format(places[0], places[1], places[2]))
    print('_______|_______|_______')
    print('       |       |')
    print('   {}   |   {}   |   {}' .format(places[3], places[4], places[5]))
    print('_______|_______|_______')
    print('       |       |')
    print('   {}   |   {}   |   {}' .format(places[6], places[7], places[8]))
    print('       |       |')

# %%
bb()
# Out:
#        |       |
#    1   |   2   |   3
# _______|_______|_______
#        |       |
#    4   |   5   |   6
# _______|_______|_______
#        |       |
#    7   |   8   |   9
#        |       |

# %%
# places[0] = 'X'
# places[1] = 'X'
# places[2] = 'X'

# %%
bb()
# Out:
#        |       |
#    1   |   2   |   3
# _______|_______|_______
#        |       |
#    4   |   5   |   6
# _______|_______|_______
#        |       |
#    7   |   8   |   9
#        |       |

# %%
def inst():
    print('Welcome to Py Tick Tack Toe')
    print('')
    print('You will be "X" while your opponent will be "O"')
    print('')
    print('Please select a number square that has not been taken')
    print('If you get three squares in a row, you win!')

# %%
inst()
# Out:
# Welcome to Py Tick Tack Toe
#
# You will be "X" while your opponent will be "O"
#
# Please select a number square that has not been taken
# If you get three squares in a row, you win!

# %%
def selectionCheck(choice, places):
    if(type(choice) == int):
        if(choice in places):
            return True
        else:
            return False
    else:
        return False

# %%
def compChoice():
    out = random.randint(1, 9)

    if(selectionCheck(out, places)):
        return out
    else:
        print('call compChoice()')
        return compChoice()

# %%
print(compChoice())
print(compChoice())
print(compChoice())
print(compChoice())
print(compChoice())
print(compChoice())
print(compChoice())
print(compChoice())
print(compChoice())
print(compChoice())
# Out:
# 6
# 9
# 4
# 2
# 9
# 8
# 3
# 4
# 6
# 7

# %%
# Player Choice
def playerChoice():
    try:
        selection = int(input(
            'Please select a number square that has not been taken\n'))
    except ValueError:
        print('That was not a number...')
        return playerChoice()

    if(selectionCheck(selection, places)):
        return selection
    else:
        print("I'm sorry, that is an invalid input.")
        return playerChoice()

# %%
# Replace Square number with X or O
def replaceSquare(xo, selection, places):
    for i in range(len(places)):
        if places[i] == selection:
            places[i] = xo
    bb()
    return places

# %%
# replaceSquare('X', 5, places)

# %%
# Winner?
def checkWinner(playerSelections, playerTurn):
    if playerSelections == [1, 2, 3]:
        print("winner!!!")
    else:
        playerTurn = not playerTurn
        runGame(playerTurn)

# %%
print(len(playerChoices))
# Out:
# 0

# %%
# Run Game (Start with player)
def runGame(playerTurn):

    if(playerTurn):
        # Displays
        print('--------> Player\'s Move <--------\n')
        # Player selects
        selection = playerChoice()
        # Store selection in player list
        playerChoices.append(selection)
        # Change Board list
        # Rewrite Board
        replaceSquare('X', selection, places)

        # Check if there is a win
        # change players
        checkWinner(playerChoices, playerTurn)

        print('\n')

    else:
        # Displays
        print('--------> Computers\'s Move <--------\n')

        # Comp selects
        selection = compChoice()
        # Store selection in comp list
        compChoices.append(selection)
        # Change Board list
        # Rewrite Board
        replaceSquare('O', selection, places)

        # Check if there is a win
        # change players
        checkWinner(compChoices, playerTurn)

        print('\n')

# %%
runGame(playerTurn)
# Out:
# --------> Player's Move <--------
#
# Please select a number square that has not been taken
# 1
#        |       |
#    X   |   2   |   3
# _______|_______|_______
#        |       |
#    4   |   5   |   6
# _______|_______|_______
#        |       |
#    7   |   8   |   9
#        |       |
# --------> Computers's Move <--------
#
#        |       |
#    X   |   O   |   3
# _______|_______|_______
#        |       |
#    4   |   5   |   6
# _______|_______|_______
#        |       |
#    7   |   8   |   9
#        |       |
# --------> Player's Move <--------
#
# Please select a number square that has not been taken
# 3
#        |       |
#    X   |   O   |   X
# _______|_______|_______
#        |       |
#    4   |   5   |   6
# _______|_______|_______
#        |       |
#    7   |   8   |   9
#        |       |
# --------> Computers's Move <--------
#
#        |       |
#    X   |   O   |   X
# _______|_______|_______
#        |       |
#    O   |   5   |   6
# _______|_______|_______
#        |       |
#    7   |   8   |   9
#        |       |
# --------> Player's Move <--------
#
# Please select a number square that has not been taken
# 9
#        |       |
#    X   |   O   |   X
# _______|_______|_______
#        |       |
#    O   |   5   |   6
# _______|_______|_______
#        |       |
#    7   |   8   |   X
#        |       |
# --------> Computers's Move <--------
#
#        |       |
#    X   |   O   |   X
# _______|_______|_______
#        |       |
#    O   |   5   |   O
# _______|_______|_______
#        |       |
#    7   |   8   |   X
#        |       |
# --------> Player's Move <--------
#
# Please select a number square that has not been taken
# 5
#        |       |
#    X   |   O   |   X
# _______|_______|_______
#        |       |
#    O   |   X   |   O
# _______|_______|_______
#        |       |
#    7   |   8   |   X
#        |       |
# --------> Computers's Move <--------
#
# call compChoice()
# call compChoice()
#        |       |
#    X   |   O   |   X
# _______|_______|_______
#        |       |
#    O   |   X   |   O
# _______|_______|_______
#        |       |
#    7   |   O   |   X
#        |       |
# --------> Player's Move <--------
#
# Please select a number square that has not been taken
# 7
#        |       |
#    X   |   O   |   X
# _______|_______|_______
#        |       |
#    O   |   X   |   O
# _______|_______|_______
#        |       |
#    X   |   O   |   X
#        |       |
# --------> Computers's Move <--------
#
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# call compChoice()
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/threading.py:1073, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1072 try:
# -> 1073     if lock.acquire(block, timeout):
#    1074         lock.release()
#
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# RecursionError                            Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 runGame(playerTurn)
#
# Input In [17], in runGame(playerTurn)
#      13     replaceSquare('X', selection, places)
#      15     # Check if there is a win
#      16     # change players
# ---> 17     checkWinner(playerChoices, playerTurn)
#      19     print('\n')
#      21 else:
#      22     # Displays
#
# Input In [15], in checkWinner(playerSelections, playerTurn)
#       5 else:
#       6     playerTurn = not playerTurn
# ----> 7     runGame(playerTurn)
#
# Input In [17], in runGame(playerTurn)
#      31 replaceSquare('O', selection, places)
#      33 # Check if there is a win
#      34 # change players
# ---> 35 checkWinner(compChoices, playerTurn)
#      37 print('\n')
#
# Input In [15], in checkWinner(playerSelections, playerTurn)
#       5 else:
#       6     playerTurn = not playerTurn
# ----> 7     runGame(playerTurn)
#
# Input In [17], in runGame(playerTurn)
#      13     replaceSquare('X', selection, places)
#      15     # Check if there is a win
#      16     # change players
# ---> 17     checkWinner(playerChoices, playerTurn)
#      19     print('\n')
#      21 else:
#      22     # Displays
#
#     [... skipping similar frames: checkWinner at line 7 (1 times)]
#
# Input In [17], in runGame(playerTurn)
#      31 replaceSquare('O', selection, places)
#      33 # Check if there is a win
#      34 # change players
# ---> 35 checkWinner(compChoices, playerTurn)
#      37 print('\n')
#
#     [... skipping similar frames: checkWinner at line 7 (4 times), runGame at line 17 (2 times), runGame at line 35 (1 times)]
#
# Input In [17], in runGame(playerTurn)
#      31 replaceSquare('O', selection, places)
#      33 # Check if there is a win
#      34 # change players
# ---> 35 checkWinner(compChoices, playerTurn)
#      37 print('\n')
#
#     [... skipping similar frames: checkWinner at line 7 (1 times)]
#
# Input In [17], in runGame(playerTurn)
#      13     replaceSquare('X', selection, places)
#      15     # Check if there is a win
#      16     # change players
# ---> 17     checkWinner(playerChoices, playerTurn)
#      19     print('\n')
#      21 else:
#      22     # Displays
#
# Input In [15], in checkWinner(playerSelections, playerTurn)
#       5 else:
#       6     playerTurn = not playerTurn
# ----> 7     runGame(playerTurn)
#
# Input In [17], in runGame(playerTurn)
#      23 print('--------> Computers\'s Move <--------\n')
#      25 # Comp selects
# ---> 26 selection = compChoice()
#      27 # Store selection in comp list
#      28 compChoices.append(selection)
#
# Input In [10], in compChoice()
#       6 else:
#       7     print('call compChoice()')
# ----> 8     return compChoice()
#
# Input In [10], in compChoice()
#       6 else:
#       7     print('call compChoice()')
# ----> 8     return compChoice()
#
#     [... skipping similar frames: compChoice at line 8 (2945 times)]
#
# Input In [10], in compChoice()
#       6 else:
#       7     print('call compChoice()')
# ----> 8     return compChoice()
#
# Input In [10], in compChoice()
#       5     return out
#       6 else:
# ----> 7     print('call compChoice()')
#       8     return compChoice()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py:531, in OutStream.write(self, string)
#     529 is_child = (not self._is_master_process())
#     530 # only touch the buffer in the IO thread to avoid races
# --> 531 self.pub_thread.schedule(lambda: self._buffer.write(string))
#     532 if is_child:
#     533     # mp.Pool cannot be trusted to flush promptly (or ever),
#     534     # and this helps.
#     535     if self._subprocess_flush_pending:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py:213, in IOPubThread.schedule(self, f)
#     208 def schedule(self, f):
#     209     """Schedule a function to be called in our IO thread.
#     210
#     211     If the thread is not running, call immediately.
#     212     """
# --> 213     if self.thread.is_alive():
#     214         self._events.append(f)
#     215         # wake event thread (message content is ignored)
#
# File ~/opt/anaconda3/lib/python3.9/threading.py:1137, in Thread.is_alive(self)
#    1135 if self._is_stopped or not self._started.is_set():
#    1136     return False
# -> 1137 self._wait_for_tstate_lock(False)
#    1138 return not self._is_stopped
#
# File ~/opt/anaconda3/lib/python3.9/threading.py:1077, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1075         self._stop()
#    1076 except:
# -> 1077     if lock.locked():
#    1078         # bpo-45274: lock.acquire() acquired the lock, but the function
#    1079         # was interrupted with an exception before reaching the
#    1080         # lock.release(). It can happen if a signal handler raises an
#    1081         # exception, like CTRL+C which raises KeyboardInterrupt.
#    1082         lock.release()
#    1083         self._stop()
#
# RecursionError: maximum recursion depth exceeded while calling a Python object

# %%
def contGame():
    choice = input('Would you like to play again? (Yes or Now)')
    
    if(lower(choice) == 'yes' or lower(choice) == 'y'):
        # return runGame(playerTurn)
        print('you chose yes')
    elif(lower(choice) == 'no' or lower(choice) == 'n'):
        # return endGame()
        print('you chose no')
    else:
        print('That was an invalid answer...')
        return contGame():
# Out:
#   Input In [8]
#     switch input('Would you like to play again? (Yes or Now)'):
#            ^
# SyntaxError: invalid syntax

# %%
contGame()
# Out:
# Would you like to play again? (Yes or Now)Y
